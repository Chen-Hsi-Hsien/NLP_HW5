# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
from tensorflow.keras import optimizers
import numpy as np

data = []
en_data = []
ch_data = []

def extract(string):
    for ch in string :
        if u'\u4e00' <= ch <= u'\u9fff':
            return True
    return False

for line in open('/content/drive/MyDrive/Colab Notebooks/translation2019zh_train.json', 'r', encoding='utf-8'):
    data.append(json.loads(line))  


for i in range(len(data)):
    if extract(data[i]['chinese']) == True :
        if len(data[i]['chinese']) < 10:
            en_data.append(data[i]['english'])
            ch_data.append('\t'+data[i]['chinese']+'。')
        if len(ch_data) == 100 :
            break
data = []

# %%
en_vocab = set(''.join(en_data))
id2en = list(en_vocab)
en2id = {c:i for i,c in enumerate(id2en)}

# 分別生成中英文字典
ch_vocab = set(''.join(ch_data))
id2ch = list(ch_vocab)
ch2id = {c:i for i,c in enumerate(id2ch)}

# %%
for i in range(10):
  print(en_data[i],"\n")
# Out:
# Look at these coasters over here.
#
# Choose a recorder.
#
# I hadn't paid the telephone bill.
#
# That's easier said than done, of course.
#
# Side-to-Side Movements.
#
# about like 80 degrees.
#
# We all are from Shandong.
#
# She was possessed by a devil.
#
# This wool knits up well.
#
# The majority was wrong last time.

# %%
en_num_data = [[en2id[en] for en in line ] for line in en_data]
ch_num_data = [[ch2id[ch] for ch in line] for line in ch_data]
de_num_data = [[ch2id[ch] for ch in line][1:] for line in ch_data]
data = []

# %%
import numpy as np

# 獲取輸入輸出端的最大長度
max_encoder_seq_length = max([len(txt) for txt in en_num_data])
max_decoder_seq_length = max([len(txt) for txt in ch_num_data])
print('max encoder length:', max_encoder_seq_length)
print('max decoder length:', max_decoder_seq_length)

# 將數據進行onehot處理
encoder_input_data = np.zeros((len(en_num_data), max_encoder_seq_length, len(en2id)), dtype='float32')
decoder_input_data = np.zeros((len(ch_num_data), max_decoder_seq_length, len(ch2id)), dtype='float32')
decoder_target_data = np.zeros((len(ch_num_data), max_decoder_seq_length, len(ch2id)), dtype='float32')

for i in range(len(ch_num_data)):
    for t, j in enumerate(en_num_data[i]):
        encoder_input_data[i, t, j] = 1.
    for t, j in enumerate(ch_num_data[i]):
        decoder_input_data[i, t, j] = 1.
    for t, j in enumerate(de_num_data[i]):
        decoder_target_data[i, t, j] = 1.
# Out:
# max encoder length: 49
# max decoder length: 11

# %%
# =======預定義模型參數========
EN_VOCAB_SIZE = len(en2id)
CH_VOCAB_SIZE = len(ch2id)
HIDDEN_SIZE = 256

LEARNING_RATE = 0.001
BATCH_SIZE = 10
EPOCHS = 400

# %%
from keras.models import Model
from keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.optimizers import Adam 
import numpy as np

# ==============encoder=============
encoder_inputs = Input(shape=(None, EN_VOCAB_SIZE))
#emb_inp = Embedding(output_dim=HIDDEN_SIZE, input_dim=EN_VOCAB_SIZE)(encoder_inputs)
encoder_h1, encoder_state_h1, encoder_state_c1 = LSTM(HIDDEN_SIZE, return_sequences=True, return_state=True)(encoder_inputs)
encoder_h2, encoder_state_h2, encoder_state_c2 = LSTM(HIDDEN_SIZE, return_state=True)(encoder_h1)

# %%
# ==============decoder=============
decoder_inputs = Input(shape=(None, CH_VOCAB_SIZE))

#emb_target = Embedding(output_dim=HIDDEN_SIZE, input_dim=CH_VOCAB_SIZE, mask_zero=True)(decoder_inputs)
lstm1 = LSTM(HIDDEN_SIZE, return_sequences=True, return_state=True)
lstm2 = LSTM(HIDDEN_SIZE, return_sequences=True, return_state=True)
decoder_dense = Dense(CH_VOCAB_SIZE, activation='softmax')

decoder_h1, _, _ = lstm1(decoder_inputs, initial_state=[encoder_state_h1, encoder_state_c1])
decoder_h2, _, _ = lstm2(decoder_h1, initial_state=[encoder_state_h2, encoder_state_c2])
decoder_outputs = decoder_dense(decoder_h2)

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
opt = Adam(lr=LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=BATCH_SIZE,
          epochs=EPOCHS,
          validation_split=0.)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 66)]   0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None, 403)]  0
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, None, 256),  330752      input_1[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, None, 256),  675840      input_2[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 256), (None, 525312      lstm[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 256),  525312      lstm_2[0][0]
#                                                                  lstm_1[0][1]
#                                                                  lstm_1[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 403)    103571      lstm_3[0][0]
# ==================================================================================================
# Total params: 2,160,787
# Trainable params: 2,160,787
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/400
# 10/10 [==============================] - 6s 62ms/step - loss: 4.5235 - accuracy: 0.1464
# Epoch 2/400
# 10/10 [==============================] - 1s 61ms/step - loss: 4.0026 - accuracy: 0.1709
# Epoch 3/400
# 10/10 [==============================] - 1s 62ms/step - loss: 3.8650 - accuracy: 0.1736
# Epoch 4/400
# 10/10 [==============================] - 1s 61ms/step - loss: 3.7619 - accuracy: 0.1791
# Epoch 5/400
# 10/10 [==============================] - 1s 61ms/step - loss: 3.7174 - accuracy: 0.1800
# Epoch 6/400
# 10/10 [==============================] - 1s 61ms/step - loss: 3.6739 - accuracy: 0.1809
# Epoch 7/400
# 10/10 [==============================] - 1s 61ms/step - loss: 3.6351 - accuracy: 0.1818
# Epoch 8/400
# 10/10 [==============================] - 1s 63ms/step - loss: 3.5994 - accuracy: 0.1800
# Epoch 9/400
# 10/10 [==============================] - 1s 64ms/step - loss: 3.5682 - accuracy: 0.1727
# Epoch 10/400
# 10/10 [==============================] - 1s 59ms/step - loss: 3.5362 - accuracy: 0.1827
# Epoch 11/400
# 10/10 [==============================] - 1s 60ms/step - loss: 3.4898 - accuracy: 0.1864
# Epoch 12/400
# 10/10 [==============================] - 1s 60ms/step - loss: 3.4487 - accuracy: 0.1864
# Epoch 13/400
# 10/10 [==============================] - 1s 61ms/step - loss: 3.4133 - accuracy: 0.1873
# Epoch 14/400
# 10/10 [==============================] - 1s 58ms/step - loss: 3.3617 - accuracy: 0.1873
# Epoch 15/400
# 10/10 [==============================] - 1s 59ms/step - loss: 3.3097 - accuracy: 0.1873
# Epoch 16/400
# 10/10 [==============================] - 1s 59ms/step - loss: 3.2785 - accuracy: 0.1882
# Epoch 17/400
# 10/10 [==============================] - 1s 59ms/step - loss: 3.2323 - accuracy: 0.1918
# Epoch 18/400
# 10/10 [==============================] - 1s 61ms/step - loss: 3.2102 - accuracy: 0.1909
# Epoch 19/400
# 10/10 [==============================] - 1s 60ms/step - loss: 3.1634 - accuracy: 0.1918
# Epoch 20/400
# 10/10 [==============================] - 1s 60ms/step - loss: 3.1179 - accuracy: 0.1918
# Epoch 21/400
# 10/10 [==============================] - 1s 60ms/step - loss: 3.0781 - accuracy: 0.1918
# Epoch 22/400
# 10/10 [==============================] - 1s 58ms/step - loss: 3.0461 - accuracy: 0.1891
# Epoch 23/400
# 10/10 [==============================] - 1s 59ms/step - loss: 3.0154 - accuracy: 0.1918
# Epoch 24/400
# 10/10 [==============================] - 1s 60ms/step - loss: 2.9917 - accuracy: 0.1955
# Epoch 25/400
# 10/10 [==============================] - 1s 59ms/step - loss: 2.9464 - accuracy: 0.1945
# Epoch 26/400
# 10/10 [==============================] - 1s 59ms/step - loss: 2.9308 - accuracy: 0.1936
# Epoch 27/400
# 10/10 [==============================] - 1s 61ms/step - loss: 2.8980 - accuracy: 0.1955
# Epoch 28/400
# 10/10 [==============================] - 1s 60ms/step - loss: 2.8812 - accuracy: 0.1936
# Epoch 29/400
# 10/10 [==============================] - 1s 61ms/step - loss: 2.8497 - accuracy: 0.2082
# Epoch 30/400
# 10/10 [==============================] - 1s 59ms/step - loss: 2.8100 - accuracy: 0.2045
# Epoch 31/400
# 10/10 [==============================] - 1s 59ms/step - loss: 2.7869 - accuracy: 0.2064
# Epoch 32/400
# 10/10 [==============================] - 1s 62ms/step - loss: 2.7534 - accuracy: 0.2000
# Epoch 33/400
# 10/10 [==============================] - 1s 60ms/step - loss: 2.7282 - accuracy: 0.2073
# Epoch 34/400
# 10/10 [==============================] - 1s 59ms/step - loss: 2.7300 - accuracy: 0.2136
# Epoch 35/400
# 10/10 [==============================] - 1s 59ms/step - loss: 2.6817 - accuracy: 0.2236
# Epoch 36/400
# 10/10 [==============================] - 1s 60ms/step - loss: 2.6188 - accuracy: 0.2191
# Epoch 37/400
# 10/10 [==============================] - 1s 60ms/step - loss: 2.5788 - accuracy: 0.2236
# Epoch 38/400
# 10/10 [==============================] - 1s 60ms/step - loss: 2.5253 - accuracy: 0.2409
# Epoch 39/400
# 10/10 [==============================] - 1s 60ms/step - loss: 2.4849 - accuracy: 0.2518
# Epoch 40/400
# 10/10 [==============================] - 1s 60ms/step - loss: 2.4395 - accuracy: 0.2691
# Epoch 41/400
# 10/10 [==============================] - 1s 61ms/step - loss: 2.3997 - accuracy: 0.2791
# Epoch 42/400
# 10/10 [==============================] - 1s 59ms/step - loss: 2.3573 - accuracy: 0.2918
# Epoch 43/400
# 10/10 [==============================] - 1s 59ms/step - loss: 2.3085 - accuracy: 0.3036
# Epoch 44/400
# 10/10 [==============================] - 1s 59ms/step - loss: 2.2634 - accuracy: 0.3127
# Epoch 45/400
# 10/10 [==============================] - 1s 61ms/step - loss: 2.2552 - accuracy: 0.3218
# Epoch 46/400
# 10/10 [==============================] - 1s 58ms/step - loss: 2.2046 - accuracy: 0.3418
# Epoch 47/400
# 10/10 [==============================] - 1s 59ms/step - loss: 2.1940 - accuracy: 0.3455
# Epoch 48/400
# 10/10 [==============================] - 1s 59ms/step - loss: 2.1316 - accuracy: 0.3655
# Epoch 49/400
# 10/10 [==============================] - 1s 62ms/step - loss: 2.0992 - accuracy: 0.3682
# Epoch 50/400
# 10/10 [==============================] - 1s 58ms/step - loss: 2.0264 - accuracy: 0.3891
# Epoch 51/400
# 10/10 [==============================] - 1s 57ms/step - loss: 1.9546 - accuracy: 0.4164
# Epoch 52/400
# 10/10 [==============================] - 1s 59ms/step - loss: 1.8857 - accuracy: 0.4227
# Epoch 53/400
# 10/10 [==============================] - 1s 58ms/step - loss: 1.8166 - accuracy: 0.4482
# Epoch 54/400
# 10/10 [==============================] - 1s 58ms/step - loss: 1.7620 - accuracy: 0.4591
# Epoch 55/400
# 10/10 [==============================] - 1s 59ms/step - loss: 1.7084 - accuracy: 0.4827
# Epoch 56/400
# 10/10 [==============================] - 1s 59ms/step - loss: 1.6575 - accuracy: 0.4964
# Epoch 57/400
# 10/10 [==============================] - 1s 60ms/step - loss: 1.6110 - accuracy: 0.5055
# Epoch 58/400
# 10/10 [==============================] - 1s 59ms/step - loss: 1.5694 - accuracy: 0.5064
# Epoch 59/400
# 10/10 [==============================] - 1s 59ms/step - loss: 1.5225 - accuracy: 0.5255
# Epoch 60/400
# 10/10 [==============================] - 1s 58ms/step - loss: 1.4648 - accuracy: 0.5318
# Epoch 61/400
# 10/10 [==============================] - 1s 61ms/step - loss: 1.4285 - accuracy: 0.5473
# Epoch 62/400
# 10/10 [==============================] - 1s 62ms/step - loss: 1.3856 - accuracy: 0.5582
# Epoch 63/400
# 10/10 [==============================] - 1s 59ms/step - loss: 1.3450 - accuracy: 0.5582
# Epoch 64/400
# 10/10 [==============================] - 1s 60ms/step - loss: 1.3179 - accuracy: 0.5664
# Epoch 65/400
# 10/10 [==============================] - 1s 60ms/step - loss: 1.3485 - accuracy: 0.5545
# Epoch 66/400
# 10/10 [==============================] - 1s 60ms/step - loss: 1.3946 - accuracy: 0.5409
# Epoch 67/400
# 10/10 [==============================] - 1s 58ms/step - loss: 1.3854 - accuracy: 0.5436
# Epoch 68/400
# 10/10 [==============================] - 1s 59ms/step - loss: 1.3132 - accuracy: 0.5618
# Epoch 69/400
# 10/10 [==============================] - 1s 61ms/step - loss: 1.4712 - accuracy: 0.5400
# Epoch 70/400
# 10/10 [==============================] - 1s 59ms/step - loss: 1.3004 - accuracy: 0.5564
# Epoch 71/400
# 10/10 [==============================] - 1s 58ms/step - loss: 1.1947 - accuracy: 0.5745
# Epoch 72/400
# 10/10 [==============================] - 1s 58ms/step - loss: 1.3199 - accuracy: 0.5518
# Epoch 73/400
# 10/10 [==============================] - 1s 59ms/step - loss: 1.3981 - accuracy: 0.5218
# Epoch 74/400
# 10/10 [==============================] - 1s 60ms/step - loss: 1.1197 - accuracy: 0.5927
# Epoch 75/400
# 10/10 [==============================] - 1s 59ms/step - loss: 1.1075 - accuracy: 0.5955
# Epoch 76/400
# 10/10 [==============================] - 1s 57ms/step - loss: 1.0308 - accuracy: 0.6036
# Epoch 77/400
# 10/10 [==============================] - 1s 59ms/step - loss: 1.0005 - accuracy: 0.6118
# Epoch 78/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.9713 - accuracy: 0.6127
# Epoch 79/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.9451 - accuracy: 0.6236
# Epoch 80/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.9119 - accuracy: 0.6309
# Epoch 81/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.8871 - accuracy: 0.6345
# Epoch 82/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.8667 - accuracy: 0.6382
# Epoch 83/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.8442 - accuracy: 0.6400
# Epoch 84/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.8261 - accuracy: 0.6409
# Epoch 85/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.8034 - accuracy: 0.6509
# Epoch 86/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.7862 - accuracy: 0.6545
# Epoch 87/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.7735 - accuracy: 0.6555
# Epoch 88/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.7575 - accuracy: 0.6555
# Epoch 89/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.7412 - accuracy: 0.6609
# Epoch 90/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.7246 - accuracy: 0.6636
# Epoch 91/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.7112 - accuracy: 0.6655
# Epoch 92/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.6950 - accuracy: 0.6573
# Epoch 93/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.6793 - accuracy: 0.6673
# Epoch 94/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.6713 - accuracy: 0.6691
# Epoch 95/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.6609 - accuracy: 0.6718
# Epoch 96/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.6484 - accuracy: 0.6718
# Epoch 97/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.6416 - accuracy: 0.6745
# Epoch 98/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.6288 - accuracy: 0.6764
# Epoch 99/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.6165 - accuracy: 0.6827
# Epoch 100/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.6062 - accuracy: 0.6782
# Epoch 101/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.6055 - accuracy: 0.6782
# Epoch 102/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.5959 - accuracy: 0.6855
# Epoch 103/400
# 10/10 [==============================] - 1s 62ms/step - loss: 0.6011 - accuracy: 0.6736
# Epoch 104/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.7391 - accuracy: 0.6573
# Epoch 105/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.7762 - accuracy: 0.6445
# Epoch 106/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.7163 - accuracy: 0.6609
# Epoch 107/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.6355 - accuracy: 0.6736
# Epoch 108/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.5937 - accuracy: 0.6864
# Epoch 109/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.5578 - accuracy: 0.6845
# Epoch 110/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.5369 - accuracy: 0.6955
# Epoch 111/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.5223 - accuracy: 0.7018
# Epoch 112/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.5116 - accuracy: 0.6927
# Epoch 113/400
# 10/10 [==============================] - 1s 63ms/step - loss: 0.5028 - accuracy: 0.7027
# Epoch 114/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.4873 - accuracy: 0.7045
# Epoch 115/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.4804 - accuracy: 0.7045
# Epoch 116/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.4735 - accuracy: 0.7055
# Epoch 117/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.4645 - accuracy: 0.7045
# Epoch 118/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.4530 - accuracy: 0.7073
# Epoch 119/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.4415 - accuracy: 0.7100
# Epoch 120/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.4313 - accuracy: 0.7100
# Epoch 121/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.4235 - accuracy: 0.7100
# Epoch 122/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.4161 - accuracy: 0.7064
# Epoch 123/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.4056 - accuracy: 0.7109
# Epoch 124/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.4040 - accuracy: 0.7082
# Epoch 125/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3947 - accuracy: 0.7091
# Epoch 126/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3870 - accuracy: 0.7136
# Epoch 127/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.3823 - accuracy: 0.7136
# Epoch 128/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.3718 - accuracy: 0.7182
# Epoch 129/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3655 - accuracy: 0.7173
# Epoch 130/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.3575 - accuracy: 0.7200
# Epoch 131/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.3613 - accuracy: 0.7182
# Epoch 132/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3543 - accuracy: 0.7173
# Epoch 133/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3413 - accuracy: 0.7200
# Epoch 134/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.3304 - accuracy: 0.7227
# Epoch 135/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.3233 - accuracy: 0.7282
# Epoch 136/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3199 - accuracy: 0.7291
# Epoch 137/400
# 10/10 [==============================] - 1s 62ms/step - loss: 0.3303 - accuracy: 0.7245
# Epoch 138/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.3437 - accuracy: 0.7182
# Epoch 139/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3383 - accuracy: 0.7245
# Epoch 140/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.3262 - accuracy: 0.7145
# Epoch 141/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3072 - accuracy: 0.7273
# Epoch 142/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.2980 - accuracy: 0.7318
# Epoch 143/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3053 - accuracy: 0.7309
# Epoch 144/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.3943 - accuracy: 0.7055
# Epoch 145/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.4562 - accuracy: 0.6809
# Epoch 146/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.4801 - accuracy: 0.6927
# Epoch 147/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.4071 - accuracy: 0.7091
# Epoch 148/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3792 - accuracy: 0.7100
# Epoch 149/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.3716 - accuracy: 0.7173
# Epoch 150/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.3412 - accuracy: 0.7164
# Epoch 151/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.3213 - accuracy: 0.7264
# Epoch 152/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2884 - accuracy: 0.7282
# Epoch 153/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2751 - accuracy: 0.7318
# Epoch 154/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.2706 - accuracy: 0.7309
# Epoch 155/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2598 - accuracy: 0.7336
# Epoch 156/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2644 - accuracy: 0.7282
# Epoch 157/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2554 - accuracy: 0.7318
# Epoch 158/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2565 - accuracy: 0.7336
# Epoch 159/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.2476 - accuracy: 0.7291
# Epoch 160/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2305 - accuracy: 0.7464
# Epoch 161/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2296 - accuracy: 0.7400
# Epoch 162/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2182 - accuracy: 0.7418
# Epoch 163/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2135 - accuracy: 0.7482
# Epoch 164/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2107 - accuracy: 0.7464
# Epoch 165/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2036 - accuracy: 0.7436
# Epoch 166/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2030 - accuracy: 0.7445
# Epoch 167/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.1989 - accuracy: 0.7518
# Epoch 168/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1991 - accuracy: 0.7527
# Epoch 169/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.1904 - accuracy: 0.7518
# Epoch 170/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.1823 - accuracy: 0.7555
# Epoch 171/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.1753 - accuracy: 0.7655
# Epoch 172/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.1751 - accuracy: 0.7573
# Epoch 173/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1681 - accuracy: 0.7627
# Epoch 174/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.1645 - accuracy: 0.7627
# Epoch 175/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.1578 - accuracy: 0.7664
# Epoch 176/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1542 - accuracy: 0.7664
# Epoch 177/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1528 - accuracy: 0.7673
# Epoch 178/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1485 - accuracy: 0.7727
# Epoch 179/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.1458 - accuracy: 0.7691
# Epoch 180/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.1402 - accuracy: 0.7727
# Epoch 181/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.1388 - accuracy: 0.7709
# Epoch 182/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.1387 - accuracy: 0.7718
# Epoch 183/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.1358 - accuracy: 0.7691
# Epoch 184/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.1347 - accuracy: 0.7727
# Epoch 185/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.1364 - accuracy: 0.7691
# Epoch 186/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.1981 - accuracy: 0.7518
# Epoch 187/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.2371 - accuracy: 0.7445
# Epoch 188/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2601 - accuracy: 0.7364
# Epoch 189/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.2689 - accuracy: 0.7382
# Epoch 190/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.2233 - accuracy: 0.7536
# Epoch 191/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.2020 - accuracy: 0.7573
# Epoch 192/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1810 - accuracy: 0.7536
# Epoch 193/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1755 - accuracy: 0.7591
# Epoch 194/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.1570 - accuracy: 0.7564
# Epoch 195/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.1365 - accuracy: 0.7664
# Epoch 196/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1200 - accuracy: 0.7782
# Epoch 197/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1090 - accuracy: 0.7800
# Epoch 198/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.1024 - accuracy: 0.7873
# Epoch 199/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0969 - accuracy: 0.7882
# Epoch 200/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0936 - accuracy: 0.7882
# Epoch 201/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0902 - accuracy: 0.7891
# Epoch 202/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0858 - accuracy: 0.7909
# Epoch 203/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0881 - accuracy: 0.7855
# Epoch 204/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0909 - accuracy: 0.7855
# Epoch 205/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0943 - accuracy: 0.7836
# Epoch 206/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0910 - accuracy: 0.7845
# Epoch 207/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.1078 - accuracy: 0.7791
# Epoch 208/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.1190 - accuracy: 0.7764
# Epoch 209/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.1114 - accuracy: 0.7745
# Epoch 210/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0949 - accuracy: 0.7836
# Epoch 211/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.1079 - accuracy: 0.7755
# Epoch 212/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1066 - accuracy: 0.7736
# Epoch 213/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.1008 - accuracy: 0.7800
# Epoch 214/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0924 - accuracy: 0.7800
# Epoch 215/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0795 - accuracy: 0.7873
# Epoch 216/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0754 - accuracy: 0.7873
# Epoch 217/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0727 - accuracy: 0.7864
# Epoch 218/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0643 - accuracy: 0.7918
# Epoch 219/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0587 - accuracy: 0.7918
# Epoch 220/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0548 - accuracy: 0.7927
# Epoch 221/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0507 - accuracy: 0.7927
# Epoch 222/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0490 - accuracy: 0.7936
# Epoch 223/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0465 - accuracy: 0.7936
# Epoch 224/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0462 - accuracy: 0.7936
# Epoch 225/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0442 - accuracy: 0.7936
# Epoch 226/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0421 - accuracy: 0.7945
# Epoch 227/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0403 - accuracy: 0.7945
# Epoch 228/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0385 - accuracy: 0.7945
# Epoch 229/400
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0377 - accuracy: 0.7945
# Epoch 230/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0365 - accuracy: 0.7945
# Epoch 231/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0360 - accuracy: 0.7945
# Epoch 232/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0347 - accuracy: 0.7945
# Epoch 233/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0338 - accuracy: 0.7945
# Epoch 234/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0330 - accuracy: 0.7945
# Epoch 235/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0323 - accuracy: 0.7945
# Epoch 236/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0320 - accuracy: 0.7945
# Epoch 237/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0306 - accuracy: 0.7945
# Epoch 238/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0302 - accuracy: 0.7945
# Epoch 239/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0294 - accuracy: 0.7945
# Epoch 240/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0288 - accuracy: 0.7945
# Epoch 241/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0283 - accuracy: 0.7945
# Epoch 242/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0273 - accuracy: 0.7945
# Epoch 243/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0269 - accuracy: 0.7945
# Epoch 244/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0258 - accuracy: 0.7945
# Epoch 245/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0258 - accuracy: 0.7945
# Epoch 246/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0249 - accuracy: 0.7945
# Epoch 247/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0246 - accuracy: 0.7945
# Epoch 248/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0243 - accuracy: 0.7945
# Epoch 249/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0240 - accuracy: 0.7945
# Epoch 250/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.0234 - accuracy: 0.7945
# Epoch 251/400
# 10/10 [==============================] - 1s 61ms/step - loss: 0.0231 - accuracy: 0.7945
# Epoch 252/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0224 - accuracy: 0.7945
# Epoch 253/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0226 - accuracy: 0.7945
# Epoch 254/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0220 - accuracy: 0.7945
# Epoch 255/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0220 - accuracy: 0.7945
# Epoch 256/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0236 - accuracy: 0.7927
# Epoch 257/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0224 - accuracy: 0.7945
# Epoch 258/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0212 - accuracy: 0.7945
# Epoch 259/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0222 - accuracy: 0.7945
# Epoch 260/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0212 - accuracy: 0.7945
# Epoch 261/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0211 - accuracy: 0.7945
# Epoch 262/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0205 - accuracy: 0.7945
# Epoch 263/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0198 - accuracy: 0.7945
# Epoch 264/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0196 - accuracy: 0.7945
# Epoch 265/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0191 - accuracy: 0.7945
# Epoch 266/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0189 - accuracy: 0.7945
# Epoch 267/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0193 - accuracy: 0.7945
# Epoch 268/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0191 - accuracy: 0.7945
# Epoch 269/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0198 - accuracy: 0.7945
# Epoch 270/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0277 - accuracy: 0.7936
# Epoch 271/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0654 - accuracy: 0.7864
# Epoch 272/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.1384 - accuracy: 0.7618
# Epoch 273/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1959 - accuracy: 0.7536
# Epoch 274/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.2623 - accuracy: 0.7355
# Epoch 275/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.2989 - accuracy: 0.7264
# Epoch 276/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.2412 - accuracy: 0.7400
# Epoch 277/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.2472 - accuracy: 0.7427
# Epoch 278/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.2270 - accuracy: 0.7409
# Epoch 279/400
# 10/10 [==============================] - 1s 59ms/step - loss: 0.1419 - accuracy: 0.7673
# Epoch 280/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.1068 - accuracy: 0.7709
# Epoch 281/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0983 - accuracy: 0.7791
# Epoch 282/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0938 - accuracy: 0.7764
# Epoch 283/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0777 - accuracy: 0.7818
# Epoch 284/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0795 - accuracy: 0.7782
# Epoch 285/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0917 - accuracy: 0.7764
# Epoch 286/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0786 - accuracy: 0.7755
# Epoch 287/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1093 - accuracy: 0.7682
# Epoch 288/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1075 - accuracy: 0.7664
# Epoch 289/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0786 - accuracy: 0.7755
# Epoch 290/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0633 - accuracy: 0.7873
# Epoch 291/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0448 - accuracy: 0.7909
# Epoch 292/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0369 - accuracy: 0.7927
# Epoch 293/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0317 - accuracy: 0.7927
# Epoch 294/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0261 - accuracy: 0.7945
# Epoch 295/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0249 - accuracy: 0.7936
# Epoch 296/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0222 - accuracy: 0.7945
# Epoch 297/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0209 - accuracy: 0.7945
# Epoch 298/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0200 - accuracy: 0.7945
# Epoch 299/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0191 - accuracy: 0.7945
# Epoch 300/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0186 - accuracy: 0.7945
# Epoch 301/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0182 - accuracy: 0.7945
# Epoch 302/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0176 - accuracy: 0.7945
# Epoch 303/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0173 - accuracy: 0.7945
# Epoch 304/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0170 - accuracy: 0.7945
# Epoch 305/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0167 - accuracy: 0.7945
# Epoch 306/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0164 - accuracy: 0.7945
# Epoch 307/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0162 - accuracy: 0.7945
# Epoch 308/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0158 - accuracy: 0.7945
# Epoch 309/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0157 - accuracy: 0.7945
# Epoch 310/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0154 - accuracy: 0.7945
# Epoch 311/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0152 - accuracy: 0.7945
# Epoch 312/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0150 - accuracy: 0.7945
# Epoch 313/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0148 - accuracy: 0.7945
# Epoch 314/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0146 - accuracy: 0.7945
# Epoch 315/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0144 - accuracy: 0.7945
# Epoch 316/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0143 - accuracy: 0.7945
# Epoch 317/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0141 - accuracy: 0.7945
# Epoch 318/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0139 - accuracy: 0.7945
# Epoch 319/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0137 - accuracy: 0.7945
# Epoch 320/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0136 - accuracy: 0.7945
# Epoch 321/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0135 - accuracy: 0.7945
# Epoch 322/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0134 - accuracy: 0.7945
# Epoch 323/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0132 - accuracy: 0.7945
# Epoch 324/400
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0131 - accuracy: 0.7945
# Epoch 325/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0129 - accuracy: 0.7945
# Epoch 326/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0128 - accuracy: 0.7945
# Epoch 327/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0127 - accuracy: 0.7945
# Epoch 328/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0126 - accuracy: 0.7945
# Epoch 329/400
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0125 - accuracy: 0.7945
# Epoch 330/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0123 - accuracy: 0.7945
# Epoch 331/400
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0122 - accuracy: 0.7945
# Epoch 332/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0122 - accuracy: 0.7945
# Epoch 333/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0120 - accuracy: 0.7945
# Epoch 334/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0120 - accuracy: 0.7945
# Epoch 335/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0118 - accuracy: 0.7945
# Epoch 336/400
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0117 - accuracy: 0.7945
# Epoch 337/400
# 10/10 [==============================] - 1s 58ms/step - loss: 0.0117 - accuracy: 0.7945
# Epoch 338/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0116 - accuracy: 0.7945
# Epoch 339/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0115 - accuracy: 0.7945
# Epoch 340/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0114 - accuracy: 0.7945
# Epoch 341/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0113 - accuracy: 0.7945
# Epoch 342/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0112 - accuracy: 0.7945
# Epoch 343/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0112 - accuracy: 0.7945
# Epoch 344/400
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0111 - accuracy: 0.7945
# Epoch 345/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0110 - accuracy: 0.7945
# Epoch 346/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0110 - accuracy: 0.7945
# Epoch 347/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0108 - accuracy: 0.7945
# Epoch 348/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0108 - accuracy: 0.7945
# Epoch 349/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0107 - accuracy: 0.7945
# Epoch 350/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0106 - accuracy: 0.7945
# Epoch 351/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0106 - accuracy: 0.7945
# Epoch 352/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0105 - accuracy: 0.7945
# Epoch 353/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0105 - accuracy: 0.7945
# Epoch 354/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0104 - accuracy: 0.7945
# Epoch 355/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0104 - accuracy: 0.7945
# Epoch 356/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0103 - accuracy: 0.7945
# Epoch 357/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0102 - accuracy: 0.7945
# Epoch 358/400
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0102 - accuracy: 0.7945
# Epoch 359/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0101 - accuracy: 0.7945
# Epoch 360/400
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0101 - accuracy: 0.7945
# Epoch 361/400
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0100 - accuracy: 0.7945
# Epoch 362/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0099 - accuracy: 0.7945
# Epoch 363/400
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0099 - accuracy: 0.7945
# Epoch 364/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0098 - accuracy: 0.7945
# Epoch 365/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0098 - accuracy: 0.7945
# Epoch 366/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0097 - accuracy: 0.7945
# Epoch 367/400
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0097 - accuracy: 0.7945
# Epoch 368/400
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0096 - accuracy: 0.7945
# Epoch 369/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0096 - accuracy: 0.7945
# Epoch 370/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0095 - accuracy: 0.7945
# Epoch 371/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0095 - accuracy: 0.7945
# Epoch 372/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0094 - accuracy: 0.7945
# Epoch 373/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0094 - accuracy: 0.7945
# Epoch 374/400
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0093 - accuracy: 0.7945
# Epoch 375/400
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0093 - accuracy: 0.7945
# Epoch 376/400
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0092 - accuracy: 0.7945
# Epoch 377/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0092 - accuracy: 0.7945
# Epoch 378/400
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0091 - accuracy: 0.7945
# Epoch 379/400
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0091 - accuracy: 0.7945
# Epoch 380/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0090 - accuracy: 0.7945
# Epoch 381/400
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0090 - accuracy: 0.7945
# Epoch 382/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0090 - accuracy: 0.7945
# Epoch 383/400
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0089 - accuracy: 0.7945
# Epoch 384/400
# 10/10 [==============================] - 1s 50ms/step - loss: 0.0089 - accuracy: 0.7945
# Epoch 385/400
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0088 - accuracy: 0.7945
# Epoch 386/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0088 - accuracy: 0.7945
# Epoch 387/400
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0087 - accuracy: 0.7945
# Epoch 388/400
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0087 - accuracy: 0.7945
# Epoch 389/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0087 - accuracy: 0.7945
# Epoch 390/400
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0086 - accuracy: 0.7945
# Epoch 391/400
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0086 - accuracy: 0.7945
# Epoch 392/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0085 - accuracy: 0.7945
# Epoch 393/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0085 - accuracy: 0.7945
# Epoch 394/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0084 - accuracy: 0.7945
# Epoch 395/400
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0084 - accuracy: 0.7945
# Epoch 396/400
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0084 - accuracy: 0.7945
# Epoch 397/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0083 - accuracy: 0.7945
# Epoch 398/400
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0083 - accuracy: 0.7945
# Epoch 399/400
# 10/10 [==============================] - 1s 55ms/step - loss: 0.0082 - accuracy: 0.7945
# Epoch 400/400
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0083 - accuracy: 0.7945

# %%
# encoder模型和訓練相同
encoder_model = Model(encoder_inputs, [encoder_state_h1, encoder_state_c1, encoder_state_h2, encoder_state_c2])

# 預測模型中的decoder的初始化狀態需要傳入新的狀態
decoder_state_input_h1 = Input(shape=(HIDDEN_SIZE,))
decoder_state_input_c1 = Input(shape=(HIDDEN_SIZE,))
decoder_state_input_h2 = Input(shape=(HIDDEN_SIZE,))
decoder_state_input_c2 = Input(shape=(HIDDEN_SIZE,))

# 使用傳入的值來初始化當前模型的輸入狀態
decoder_h1, state_h1, state_c1 = lstm1(decoder_inputs, initial_state=[decoder_state_input_h1, decoder_state_input_c1])
decoder_h2, state_h2, state_c2 = lstm2(decoder_h1, initial_state=[decoder_state_input_h2, decoder_state_input_c2])
decoder_outputs = decoder_dense(decoder_h2)

decoder_model = Model([decoder_inputs, decoder_state_input_h1, decoder_state_input_c1, decoder_state_input_h2, decoder_state_input_c2], 
                      [decoder_outputs, state_h1, state_c1, state_h2, state_c2])

# %%
TestPath = '/content/drive/MyDrive/Colab Notebooks/translation2019zh_valid.json'
textsC = []
textsE = []
file = open(TestPath, 'r', encoding='utf-8')
dataR = []
for line in file.readlines():
    dataLine = json.loads(line)
    dataR.append(dataLine)

for data1 in dataR:
    textsE.append(data1['english'])
    textsC.append(data1['chinese'])

for k in range(100):
    test_data = encoder_input_data[k:k+1]
    A1, B1, A2, B2 = encoder_model.predict(test_data)
    target_seq = np.zeros((1, 1, CH_VOCAB_SIZE))
    target_seq[0, 0, ch2id['\t']] = 1
    outputs = []
    while True:
        output_tokens, A1, B1, A2, B2 = decoder_model.predict([target_seq, A1, B1, A2, B2])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        outputs.append(sampled_token_index)
        target_seq = np.zeros((1, 1, CH_VOCAB_SIZE))
        target_seq[0, 0, sampled_token_index] = 1
        if sampled_token_index == ch2id['。']: break
    
    print(str(k+1) + ":" + en_data[k])
    print(''.join([id2ch[i] for i in outputs]))
# Out:
# 1:Look at these coasters over here.
# 看看这边的杯垫。
# 2:Choose a recorder.
# 选择一个记录员.。
# 3:I hadn't paid the telephone bill.
# 我还没交电话费。
# 4:That's easier said than done, of course.
# 当然，知易行难。
# 5:Side-to-Side Movements.
# 侧向运动。
# 6:about like 80 degrees.
# 大概华氏80度吧。
# 7:We all are from Shandong.
# 俺都是山东人。
# 8:She was possessed by a devil.
# 她着了魔。
# 9:This wool knits up well.
# 这种毛线很好织。
# 10:The majority was wrong last time.
# 方是错的。
# 11:Stone Soup Stories to Go!
# 石头汤（故事去！）。
# 12:Done. See you tomorrow.
# 一言为定。
# 13:He eased some of the strains on the poor.
# 缓解了穷人的压力。
# 14:Could it be that it was written wrongly?
# 莫非写错了?。
# 15:What a terrible temper!
# 脾气真够坏的！。
# 16:Great talents flower late.
# 大器晚成。
# 17:I forbid you to make a sortie today.
# 你今天不许出击。
# 18:C：My surname is Jiang.
# C：我姓姜。
# 19:Well, if it was greater .
# 如果拉力很大。
# 20:They looked over to the left.
# 她们朝左边看。
# 21:To supervise the management of printing industry.
# 监督管理印刷业。
# 22:no one else can see you shake your head.
# 没人看的见你摇头。
# 23:All photos dials.
# 所有照片刻盘。
# 24:Stained glass window panels;
# 彩色玻璃窗板；。
# 25:The murderer was caught red-handed.
# 凶犯当场被抓住。
# 26:You don’t love Melanie.
# 你是不爱梅兰妮的。
# 27:His style is very lucid .
# 他的文体很明畅。
# 28:At this time, there was a male cat.
# 这次是一只小公猫。
# 29:The truth has leaked out.
# 事实真相已泄露。
# 30:Material evidence must also be original.
# 物证应当提交原物。
# 31:The brother and sister quickly ran.
# 兄妹俩快步的跑着。
# 32:The ship doubled Cape Horn .
# 那船绕过合恩角。
# 33:Consider your audience.
# 考虑你的听众。
# 34:Two times five is ten.
# 二乘五等于一十。
# 35:Erhai Lake （in Yunnan Province）
# 洱海。
# 36:He is a junior it?
# 他是一个初中生吗？。
# 37:I locked all the doors.
# 我锁好了所有的门。
# 38:Problems, if any, should be solved without delay.
# 有问题要及时解决。
# 39:This is a big deal!
# 这可是件大事儿啊！。
# 40:I need some water to quench .
# 我想要些水解渴。
# 41:Helen:Hot springs in Iceland?
# 海伦：冰岛有温泉？。
# 42:Which hole is this?
# 这是几杆洞？。
# 43:The producer was Lawan Davis.
# 生产者蜡丸戴维斯。
# 44:Cuddle with your kids.
# 拥抱你的孩子。
# 45:It included in it thousands of brackets.
# 里面有上千个托座。
# 46:Deals for approval by admin.
# 交易由管理员批准。
# 47:Um, not so good.
# 嗯，这并不太妙。
# 48:Can ferrets get fleas?
# 雪貂会不会生跳蚤？。
# 49:F: Lubanga is in The Hague.
# F：在海牙。
# 50:No definite article.
# 没有定冠词。
# 51:You shit to wear underpants!
# 你丫拉屎穿裤衩呀！。
# 52:Have you got some unfinished business?
# 你还有未竟的事业？。
# 53:In Australia, this variety is called "Traminer".
# 在澳洲也称塔明那。
# 54:Gwyn: Let me take a look.
# 格温：让我来看看。
# 55:I love the subject.
# 我喜欢这个主题。
# 56:It strikes one as very strange.
# 深以为异。
# 57:It's simple: just ignore floaters .
# 很简单，无视飞蚊。
# 58:To adjust flag-down price.
# 调整起步价。
# 59:A cold wind was blowing from the north.
# 寒风自北吹来。
# 60:They live in the oceans.
# 它们生活在海洋中。
# 61:My head is still paining me.
# 我的头还在疼。
# 62:That is just a jok.
# 那不过是个笑话。
# 63:Snap placket over zip front.
# 门襟拉链扣在前面。
# 64:Where is my bus?
# 我的巴士在哪里？。
# 65:I am going to call this one. Let's see.
# 这一步为步骤。
# 66:But the little prince made no reply.
# 小王子没有回答。
# 67:Edward: That's true love.
# 爱德华：那是真爱。
# 68:Living things depend on the sunlight.
# 生物对阳光有依赖。
# 69:He was tried for murder.
# 他因谋杀罪而受审。
# 70:All casing concrete pile?
# 全套管基桩?。
# 71:Did I divide right?
# 我算得对吗。
# 72:Should I go up to the rooftop?
# 我应该到屋顶上吗？。
# 73:The girl threaded the needle for her mother.
# 女孩为妈妈穿针。
# 74:You sexy thang.
# 你这性感的家伙。
# 75:Iuml; 'll show you.
# 我给你指路。
# 76:But growing numbers moved west.
# 但越来越多的西移。
# 77:Drury officials said they …
# 象官员说，他们…。
# 78:Then I understood.
# 然后，我明白了。
# 79:My sister-in-law is pregnant.
# 我嫂嫂怀孕了。
# 80:How do you like rabbit?
# 你喜欢兔肉吗？。
# 81:Your soup and vegetables.
# 你的汤及蔬菜。
# 82:Have kids later.
# 迟点生小孩。
# 83:This is the world called "Da-Tong (Dah-Torng)".
# 这便是大同世界。
# 84:Is that a real string of pearls？
# 那串珍珠是真的吗？。
# 85:We have bow thruster .
# 我们船有艏侧推器。
# 86:Yeah. -That's right.
# 哈，是的，-对对。
# 87:I promise".
# 我保证。
# 88:It was abridged from the original work.
# 它由原著缩节而成。
# 89:It is a jiffy after three.
# 今朝是三点过几分。
# 90:Ask you how much sorrows can there be?
# 问君能有几多愁？。
# 91:The large print makes for  easier reading.
# 大号字体好读一些。
# 92:On the third floor they are selling linens.
# 四楼在卖亚麻布单。
# 93:Grain size analysis?
# 粒径分析?。
# 94:Eagles fly alone,but sheep flock together.
# 鹰爱独飞羊爱群。
# 95:You are bound to vacillate at times .
# 有时你一定会犹豫…。
# 96:No poet can poet it.
# 没有诗人可以抒怀。
# 97:I will apprise you of the situation .
# 我将把情况告知你。
# 98:Button thread easily pulled out.
# 钉钮线容易拉脱。
# 99:You've crossed a line.
# 你已经越线了。
# 100:All was quiet and not a soul was to be seen.
# 阒无一人。

# %%
data_T = []
en_data_T = []
ch_data_T = []

def extract(string):
    for ch in string :
        if u'\u4e00' <= ch <= u'\u9fff':
            return True
    return False

for line in open('/content/drive/MyDrive/Colab Notebooks/translation2019zh_valid.json', 'r', encoding='utf-8'):
    data_T.append(json.loads(line))  


for i in range(len(data_T)):
    if extract(data_T[i]['chinese']) == True :
        if len(data_T[i]['chinese']) < 10:
            en_data_T.append(data_T[i]['english'])
            ch_data_T.append('\t'+data_T[i]['chinese']+'。')
        if len(ch_data_T) == 100 :
            break
data_T = []

# %%
en_vocabT = set(''.join(en_data_T))
id2enT = list(en_vocabT)
en2idT = {c:i for i,c in enumerate(id2enT)}

# 分別生成中英文字典
ch_vocabT = set(''.join(ch_data_T))
id2chT = list(ch_vocabT)
ch2idT = {c:i for i,c in enumerate(id2chT)}

# %%
for i in range(10):
  print(en_data_T[i],"\n")
# Out:
# We should have little snacks.
#
# Take one in the street.
#
# But not often.
#
# Things that burn.
#
# Warm wind caresses my face.
#
# I'd like to send it as registered mail!
#
# These are desks.
#
# Vill there be anything else?
#
# Anything more specific?
#
# Water freezes at zero degree.
